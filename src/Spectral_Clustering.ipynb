# %% [markdown]
# # Spectral Clustering #

# %% [markdown]
# In this notebook, we experiment with spectral clustering, estimation of standard devition of the similarity function and showcase it on set of points.
# Implementation is mainly based on [A Tutorial on Spectral Clustering](https://arxiv.org/abs/0711.0189).

# %%
import Spectral_Clustering
import numpy as np
import matplotlib.pyplot as plt
from utility_tools import Data_loader

# %%
# load data for cluster 4
points = Data_loader.load_data('../data/spectral_data/points_data.mat', clusterInd=4)  

Data_loader.plotData(points)

# %%
# cluster the data
# if sigma is not specified, it is automatically estimated by the median of k-nn distances

# parameters: points: data points
#             k: number of clusters
#             sigma: sigma for similarity matrix construction
#             graphType: type of graph Laplacian 'unNormalized', 'symmetric', 'randomWalk'


# specified sigma
labelsSpecifiedSigma = Spectral_Clustering.spectral_Clustering(points, k=2, sigma=0.05, graphType='symmetric')

# automatically estimated sigma
labelsEstimatedSigma = Spectral_Clustering.spectral_Clustering(points, k=2, graphType='symmetric')

# %%
# plot results
Data_loader.plotData(points, labels=labelsSpecifiedSigma, title='Specified sigma')
Data_loader.plotData(points, labels=labelsEstimatedSigma, title='Estimated sigma')

# %%
# load data for cluster 1
points = Data_loader.load_data('../data/spectral_data/points_data.mat', clusterInd=1)

# %%
# cluster the data

# specified sigma
labelsSpecifiedSigma = Spectral_Clustering.spectral_Clustering(points, k=3, sigma=0.25, graphType='unNormalized')

# automatically estimated sigma
labelsEstimatedSigma = Spectral_Clustering.spectral_Clustering(points, k=3, graphType='unNormalized')

# %%
# plot results
Data_loader.plotData(points, labels=labelsSpecifiedSigma, title='Specified sigma')
Data_loader.plotData(points, labels=labelsEstimatedSigma, title='Estimated sigma')

# %%
# cluster 0
points = Data_loader.load_data('../data/spectral_data/points_data.mat', clusterInd=0)
# cluster
labels = Spectral_Clustering.spectral_Clustering(points, k=3, sigma=0.25, graphType='randomWalk')

Data_loader.plotData(points, labels=labels)

# %%
# cluster 2
points = Data_loader.load_data('../data/spectral_data/points_data.mat', clusterInd=2)
labels = Spectral_Clustering.spectral_Clustering(points, k=2, sigma=0.03, graphType='symmetric')
Data_loader.plotData(points, labels=labels, title='Specified sigma')
labels = Spectral_Clustering.spectral_Clustering(points, k=2, graphType='symmetric')
Data_loader.plotData(points, labels=labels, title='Estimated sigma')

# %%
# cluster 3
points = Data_loader.load_data('../data/spectral_data/points_data.mat', clusterInd=3)    
labels = Spectral_Clustering.spectral_Clustering(points, k=3, sigma=0.35, graphType='symmetric')
Data_loader.plotData(points, labels=labels)
