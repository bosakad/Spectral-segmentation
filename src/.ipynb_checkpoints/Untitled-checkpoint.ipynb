# %%
import numpy as np
import skimage
import matplotlib.pyplot as plt
import Spectral_Clustering
from utility_tools import Data_loader, Graph_Laplacian, Eigen_Solver

# %%
# use it reload module after making changes to the py files
import importlib
importlib.reload(Spectral_Clustering)
importlib.reload(Graph_Laplacian)
# Out:
# <module 'utility_tools.Graph_Laplacian' from '/home/harsh/Spectral-segmentation/src/utility_tools/Graph_Laplacian.py'>

# %%
img = skimage.io.imread('../data/spectral_data/plane.jpg').astype(np.float32)
img = img / 255

if len(img.shape) == 3:
    rgb = True
    img = img[0:300, 0:300, :]

# %%
labels = Spectral_Clustering.spectral_Segmentation(img, k=2, sigma_i=0.03, sigma_x=2, r=3, graphType='symmetric')

# %%
subplot, ax = plt.subplots(1, 3)

ax[0].imshow(img, cmap='gray')    
ax[1].imshow(labels, cmap='gray')

imgSegmented = img.copy()
imgSegmented[labels == 0] = 0
ax[2].imshow(imgSegmented, cmap='gray')

# %%
new_labels = Spectral_Clustering.post_processing(img, labels, r=5, k=2, sigma=0.03, num_iteration=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 new_labels = Spectral_Clustering.post_processing(img, labels, r=5, k=2, sigma=0.03, num_iteration=100)
#
# File ~/Spectral-segmentation/src/Spectral_Clustering.py:111, in post_processing(image, labels, r, k, sigma, num_iteration)
#     109 out_label = Graph_Laplacian.get_label_mat(labels, None, r)
#     110 probability, kernel = Graph_Laplacian.get_distance_mat(image, out_label, r)
# --> 111 influence_mat  = Graph_Laplacian.get_influence_mat(image, kernel, sigma, r)
#     112 prod = influence_mat * probability
#     114 for _ in range(num_iteration):
#
# File ~/Spectral-segmentation/src/utility_tools/Graph_Laplacian.py:260, in get_influence_mat(image, kernel, sigma, r)
#     256         sum_data += intensity_data
#     258 # data = np.exp(-sum_data / np.square(sigma))
# --> 260 return data
#
# NameError: name 'data' is not defined

# %%
subplot, ax = plt.subplots(1, 3)

ax[0].imshow(img, cmap='gray')    
ax[1].imshow(new_labels, cmap='gray')

imgSegmented = img.copy()
imgSegmented[new_labels == 0] = 0
ax[2].imshow(imgSegmented, cmap='gray')

# %%
np.sum(new_labels == labels)
# Out:
# 89540

# %%
np.prod(labels.shape)
# Out:
# 90000
